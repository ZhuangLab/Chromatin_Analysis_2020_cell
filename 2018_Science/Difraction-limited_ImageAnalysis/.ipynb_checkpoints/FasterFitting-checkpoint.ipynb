# %%
#Imports
import sys,glob,os
import numpy as np
import cPickle as pickle
sys.path.append(r'C:\Data\Alistair\code\python-functions\python-functions-library')
import TadImagingAnalysis as tia
import matplotlib.pylab as plt

# %%
#Get file paths

master_folder = r'D:\Bogdan\IMR90_C1SI15_6_26_2018'

folders = [folder for folder in glob.glob(master_folder+os.sep+'*') 
           if ('R' in os.path.basename(folder) or 'P' in os.path.basename(folder))]
#folders = [folder for folder in glob.glob(master_folder+os.sep+'*') 
#           if ('X' in os.path.basename(folder) or os.path.basename(folder) in['H1R9']) and os.path.isdir(folder)]
def get_hybe(folder):
    #this sorts by hybes.
    try: return int(os.path.basename(folder).split('H')[-1].split('R')[0])
    #try: return int(os.path.basename(folder).split('R')[-1])
    except: return np.inf
folders = np.array(folders)[np.argsort(map(get_hybe,folders))]
fovs = map(os.path.basename,glob.glob(folders[0]+os.sep+'*.dax'))
analysis_folder = master_folder+os.sep+r'Analysis'

#Load positions of selected chroms
dic = pickle.load(open(analysis_folder+os.sep+'Selected_Spot.pkl','r'))
reload(tia)
chr_pts = tia.partition_map(dic['coords'],dic['class_ids'])
fov_ids = np.unique(dic['class_ids'])

im_beads_repair = pickle.load(open(analysis_folder+os.sep+'im_beads_repair.pkl','rb'))
im_cy5_repair = pickle.load(open(analysis_folder+os.sep+'im_cy5_repair.pkl','rb'))


folders = [folder for folder in folders if os.path.exists(folder+os.sep+fovs[0])]
folders
# Out:
# ['D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H1R1',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H2R2',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H3R3',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H4R4',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H5R5',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H6R6',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H7R7',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H8R8',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H9R9',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H10R10',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H11R11',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H12R12',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H13R13',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H14R14',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H15R15',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H16R16',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H17R17',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H18R18',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H19R19',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H20R20',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H21R21',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H22R22',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H23R23',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H24R24',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H25R25',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H26R26',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H27R27',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H28R28',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H29R29',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H30R30',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H31R31',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H32R32',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H33R33',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H34R34',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H35R35',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H36R36',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H37R37',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H38R38',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H39R39',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H40R40',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H41R41',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H42R42',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H43R43',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H44R44',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H45R45',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H46R46',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H48R48',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H49R49',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H50R50',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H51R51',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H52R52',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H53R53',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H54R54',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H55R55',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H56R56',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H57R57',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H58R58',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H59R59',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H60R60',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H61R61',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H62R62',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H63R63',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H64R64',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H65R65',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H66R47',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H67R12',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H48P48',
#  'D:\\Bogdan\\IMR90_C1SI15_6_26_2018\\H47P47']

# %%
#folders = ['D:\\Bogdan\\A549_SI13Ext_D_3_26_2018\\H1R9','D:\\Bogdan\\A549_SI13Ext_D_3_26_2018\\H106X53']
reload(tia)

##where to save
analysis_folder = master_folder+os.sep+r'Analysis'
if not os.path.exists(analysis_folder):
    os.makedirs(analysis_folder)

###paramaters
overwrite=False

#drift paramaters
ref=0 #drift reference hybe
sz_ex=80 #the effective size of the cube to do drift correction
hseed_beads=150 # The minimum bead height (prefitting)
nbeads = 100 # The maximum number of beads
force_drift=False
#brightness cutoffs
low_limit=150 #the minimum prefitting signal height
bad_low_limit = 75
bad_tags = []#['R53']
prefered_limit=300 #the initial try of prefitting signal height
#distance cutoffs
cutoff_window=20 #fitted points within this distance will be reported
cutoff_chr=10 #if no prefered brightness points are detected within this distance, then include low brightness ones
from scipy.spatial.distance import cdist

#iterate through good fields of view
ind=0
folders_keep_base = folders[:]
folders_keep = list(folders_keep_base)
#itterate through fields of view
for ind in range(len(fov_ids))[:]:#[21]:#
    ##limit the folder hybes
    fov_id = fov_ids[ind]
    file_=fovs[fov_id]
    chr_pts_ = chr_pts[ind] #positions of the selected centers of chromosomes in reference frame.
    chr_pts_ = np.array(chr_pts_)[:,::-1]#zxy coords of chromosomes already in the right position
    
    #Decide where to save the candidate positions of the hybe
    fl_cands = analysis_folder+os.sep+file_.replace('.dax','__current_cand.pkl')#file where it save candidates
    fl_cor = analysis_folder+os.sep+file_.replace('.dax','__current_cor_v9.pkl')
    print fl_cands
    candid_spot={}
    
    #simplify folder and keep only what has not been analysed except for one reference.
    tags = [os.path.basename(folder) for folder in folders_keep_base]
    start=0
    if os.path.exists(fl_cands) and not overwrite:
        candid_spot = pickle.load(open(fl_cands,'rb'))
        tags_existing = []
        for key in candid_spot.keys():
            cand_dic_0 = candid_spot[key][0]
            tags_existing.extend(cand_dic_0.keys())
        tags_existing = np.unique(tags_existing)
        keep = np.array([tag not in tags_existing for tag in tags])
        folders_in_common = [folder for tag,folder in zip(tags,folders_keep) if tag in tags_existing]
        folders_keep = [folders_in_common[0]]+list(np.array(folders_keep_base)[keep])
        start = 1
    #tags = ['H2R10','H59R58','H60R59','H61R60','H62R61','H63R62','H64R63','H65R64','H66R65']
    #tags=['H2R10', 'H67P10', 'H68P53']
    #folders_keep = [os.path.dirname(folders_keep[0])+os.sep+tag for tag in tags]
    
    tags = [os.path.basename(folder) for folder in folders_keep]
    print tags
    #load data (memory mapping)
    ims_beads=[]
    ims_cy5=[]
    tags = []
    for folder in folders_keep:
        file__= folder+os.sep+file_
        if os.path.exists(file__):
            #print file__
            tags.append(os.path.basename(folder))
            im = tia.DaxReader(file__).loadMap()
            ims_beads += [im[2::2][5:-5]]
            ims_cy5 += [im[1::2][5:-5]]

    #compute the drift for the field of view
    if len(ims_beads)>1:
        #txyz_both,overwrite = tia.get_STD_beaddrift_v2(ims_beads,tags,sz_ex=sz_ex,hseed=hseed_beads,nseed=nbeads,ref=None,force=force_drift,save_file=fl_cor)
        txyz_both,_ = tia.get_STD_beaddrift(ims_beads,sz_ex=sz_ex,hseed=hseed_beads,nseed=nbeads,ref=None,force=force_drift,save_file=fl_cor)
        txyz = tia.simplify_txyz(txyz_both)
        txyz = np.array(txyz)-[txyz[ref]]

    #iterate through folders
    for iim in range(len(ims_cy5))[start:]:#skip the reference
        #iim specific vars
        im=ims_cy5[iim]
        tag = tags[iim]
        
        txyz_ = txyz[iim]
        #correct for illumination
        im=np.array(im,dtype=float)/im_cy5_repair*np.median(im_cy5_repair)
        #get the seeds
        print tag
        tia.update_candid_spot(im,low_limit,prefered_limit,chr_pts_,txyz_,tag,
                       cutoff_window,cutoff_chr,candid_spot,fl_cands)
# Out:
# D:\Bogdan\IMR90_C1SI15_6_26_2018\Analysis\Conv_zscan_00__current_cand.pkl
# ['H1R1', 'H66R47', 'H67R12']
# Aligning 0
# [-0.04307875 -0.39483762  0.11268864] [ 0.16684306 -0.2999905  -0.04412412] 62 66
# Aligning 1
# [ 0.  0.  0.] [ 0.  0.  0.] 100 100
# Aligning 2
# [ 0
# H59R59
# H60R60
# H61R61
# H62R62
# H63R63
# H64R64
# H65R65
# H66R47
# H67R12
# D:\Bogdan\IMR90_C1SI15_6_26_2018\Analysis\Conv_zscan_50__current_cand.pkl
# ['H1R1', 'H59R59', 'H60R60', 'H61R61', 'H62R62', 'H63R63', 'H64R64', 'H65R65', 'H66R47', 'H67R12']
# Aligning 0
# [-0.09610319 -0.95435266 -0.217006  ] [ 0.71209355 -1.07932912  0.01959884] 76 56
# Suspecting failure.
# [array([-0.00538941, -0.94441826, -0.25296814]), array([-0.09610319, -0.95435266, -0.217006  ])]
# Aligning 1
# [-0.06813544  1.38551176 -0.27118737] [-0.05262421  1.40969688 -0.25945004] 83 73
# Aligning 2
# [-0.29835282  0.89579151  0.27190518] [-0.08452408  0.88132308  0.30123564] 84 76
# Aligning 3
# [-0.10663249  0.57390117  0.5268376 ] [ 0.14134416  0.59579085  0.52259839] 90 78
# Aligning 4
# [-0.14472686  0.09624756 -0.42874096] [ 0.09170378  0.08991669 -0.4230301 ] 91 85
# Aligning 5
# [ 0.  0.  0.] [ 0.  0.  0.] 100 100
# Aligning 6
# [-0.10785083  0.57162099  0.33113292] [ 0.137366    0.58183805  0.32873959] 89 77
# Aligning 7
# [ 0.05013865  0.05613564  0.00437618] [ 0.20968722  0.04240225 -0.00063814] 92 81
# Aligning 8
# [-0.0952226  -0.41342269 -0.15535993] [ 0.01480379 -0.42750989 -0.1670613 ] 87 81
# Aligning 9
# [-0.1783869  -0.92605992 -0.13693924] [ 0.14445421 -0.96482862 -0.15408078] 79 78
# H59R59
# H60R60
# H61R61
# H62R62
# H63R63
# H64R64
# H65R65
# H66R47
# H67R12
# D:\Bogdan\IMR90_C1SI15_6_26_2018\Analysis\Conv_zscan_51__current_cand.pkl
# ['H1R1', 'H59R59', 'H60R60', 'H61R61', 'H62R62', 'H63R63', 'H64R64', 'H65R65', 'H66R47', 'H67R12']
# Aligning 0
# [-0.15514974  2.44353933  0.04788831] [ 0.47877411  2.598989    0.97184673] 66 53
# Suspecting failure.
# [array([ 0.36811754,  2.35684285, -0.02264818]), array([-0.15514974,  2.44353933,  0.04788831])]
# Aligning 1
# [-0.15297902  0.10366928 -0.32849064] [-0.0455981   0.11884049 -0.38134362] 84 79
# Aligning 2
# [-0.25520332  1.19416026 -0.17101437] [-0.32960364  1.16717325 -0.23913184] 79 78
# Aligning 3
# [-0.15113987  1.59940317 -0.38675649] [-0.15019749  1.63722646 -0.40415741] 77 70
# Aligning 4
# [-0.10724733  1.38182148  0.39691234] [-0.19736144  1.38076349  0.37182691] 76 74
# Aligning 5
# [ 0.  0.  0.] [ 0.  0.  0.] 99 100
# Aligning 6
# [-0.16272492  0.02589955 -0.21994319] [-0.04185238  0.02837248 -0.20893843] 83 82
# Aligning 7
# [-0.19879241  1.08148031 -0.47300351] [-0.0928648   1.04551464 -0.49137167] 78 79
# Aligning 8
# [ 0.0185908   2.52676486 -0.59336586] [ 0.00661186  2.50871748 -0.58147597] 71 72
# Aligning 9
# [-0.01500688  2.96387084  0.0901207 ] [ 0.20403949  2.94927809  0.10964001] 66 67
# H59R59
# H60R60
# H61R61
# H62R62
# H63R63
# H64R64
# H65R65
# H66R47
# H67R12

# %%
#folders = ['D:\\Bogdan\\A549_SI13Ext_D_3_26_2018\\H1R9','D:\\Bogdan\\A549_SI13Ext_D_3_26_2018\\H106X53']
reload(tia)

##where to save
analysis_folder = master_folder+os.sep+r'Analysis'
if not os.path.exists(analysis_folder):
    os.makedirs(analysis_folder)

###paramaters
overwrite=True

#drift paramaters
ref=0 #drift reference hybe
sz_ex=80 #the effective size of the cube to do drift correction
hseed_beads=150 # The minimum bead height (prefitting)
nbeads = 100 # The maximum number of beads
force_drift=False
#brightness cutoffs
low_limit=150
bad_low_limit = 75
bad_tags = []#['R53']
prefered_limit=300
#distance cutoffs
cutoff_window=20 #fitted points within this distance will be reported
cutoff_chr=10 #if no prefered brightness points are detected within this distance, then include low brightness ones
from scipy.spatial.distance import cdist

#iterate through good fields of view
ind=0
folders_keep_base = folders[:]
folders_keep = list(folders_keep_base)
for ind in range(len(fov_ids))[:]:#[21]:#
    ##limit the folder hybes
    fov_id = fov_ids[ind]
    file_=fovs[fov_id]
    chr_pts_ = chr_pts[ind]
    chr_pts_ = np.array(chr_pts_)[:,::-1]#zxy coords of chromosomes already in the right position
    fl_cands = analysis_folder+os.sep+file_.replace('.dax','__current_cand.pkl')#file where it save candidates
    fl_cor = analysis_folder+os.sep+file_.replace('.dax','__current_cor_v5.pkl')
    print fl_cands
    candid_spot={}
    #simplify folder and keep only what has not been analysed except for one reference.
    tags = [os.path.basename(folder) for folder in folders_keep_base]
    start=0
    if os.path.exists(fl_cands) and not overwrite:
        candid_spot = pickle.load(open(fl_cands,'rb'))
        tags_existing = []
        for key in candid_spot.keys():
            cand_dic_0 = candid_spot[key][0]
            tags_existing.extend(cand_dic_0.keys())
        tags_existing = np.unique(tags_existing)
        keep = np.array([tag not in tags_existing for tag in tags])
        folders_in_common = [folder for tag,folder in zip(tags,folders_keep) if tag in tags_existing]
        folders_keep = [folders_in_common[0]]+list(np.array(folders_keep_base)[keep])
        start = 1
    #tags = ['H2R10','H59R58','H60R59','H61R60','H62R61','H63R62','H64R63','H65R64','H66R65']
    #tags=['H2R10', 'H67P10', 'H68P53']
    #folders_keep = [os.path.dirname(folders_keep[0])+os.sep+tag for tag in tags]
    
    tags = [os.path.basename(folder) for folder in folders_keep]
    print tags
    #load data (memory mapping)
    ims_beads=[]
    ims_cy5=[]
    tags = []
    for folder in folders_keep:
        file__= folder+os.sep+file_
        if os.path.exists(file__):
            #print file__
            tags.append(os.path.basename(folder))
            im = tia.DaxReader(file__).loadMap()
            ims_beads += [im[2::2][5:-5]]
            ims_cy5 += [im[1::2][5:-5]]

    #compute the drift for the field of view
    if len(ims_beads)>1:
        #txyz_both,overwrite = tia.get_STD_beaddrift_v2(ims_beads,tags,sz_ex=sz_ex,hseed=hseed_beads,nseed=nbeads,ref=None,force=force_drift,save_file=fl_cor)
        txyz_both,_ = tia.get_STD_beaddrift(ims_beads,sz_ex=sz_ex,hseed=hseed_beads,nseed=nbeads,ref=None,force=force_drift,save_file=fl_cor)
        txyz = tia.simplify_txyz(txyz_both)
        txyz = np.array(txyz)-[txyz[ref]]

    #iterate through folders
    for iim in range(len(ims_cy5))[start:]:#skip the reference
        #iim specific vars
        im=ims_cy5[iim]
        tag = tags[iim]
        
        txyz_ = txyz[iim]
        #correct for illumination
        im=np.array(im,dtype=float)/im_cy5_repair*np.median(im_cy5_repair)
        #get the seeds
        ##fix bad hybes
        R='R'+tag.split('R')[-1]
        bad_ = np.any([R in tag_ for tag_ in bad_tags])
        if bad_:
            tag_=tag.replace('R','Q')
            print tag_
            tia.update_candid_spot(im,bad_low_limit,prefered_limit,chr_pts_,txyz_,tag_,
                       cutoff_window,cutoff_chr,candid_spot,fl_cands)
        print tag
        tia.update_candid_spot(im,low_limit,prefered_limit,chr_pts_,txyz_,tag,
                       cutoff_window,cutoff_chr,candid_spot,fl_cands)
# Out:
# D:\Bogdan\IMR90_5_09_2018\Analysis\Conv_zscan_00__current_cand.pkl
# ['H2R10', 'H3R11', 'H4R12', 'H5R13', 'H6R14', 'H7R15', 'H8R16', 'H9R17', 'H10R18', 'H11R19', 'H12R20', 'H13R21', 'H14R22', 'H15R23', 'H16R24', 'H17R25', 'H18R26', 'H19R27', 'H20R28', 'H21R42']
# Aligning 0
# [ -0.29351758  14.7238392  -12.93976976] [ -0.07532986  14.69214879 -12.9366738 ] 61 65
# Aligning 1
# [ -0.28671206  12.37266973 -10.83976072] [ -0.12837775  12.35115283 -10.85164416] 66 66
# Aligning 2
# [-0.4990314   9.54811136 -9.31610142] [-0.36407489  9.52635992 -9.300779  ] 72 65
# Aligning 3
# [-0.1711575   6.85485003 -7.1365043 ] [-0.03970264  6.83885707 -7.1282087 ] 75 71
# Aligning 4
# [-0.29535777  5.74991803 -5.782357  ] [-0.16117156  5.75882414 -5.77087097] 83 75
# Aligning 5
# [-0.16286333  3.95254946 -4.21811462] [-0.05502724  3.94605912 -4.21886491] 78 79
# Aligning 6
# [-0.21680302  2.71621758 -3.19642065] [-0.20676704  2.7187911  -3.20326911] 86 79
# Aligning 7
# [-0.07039143  2.98811782 -2.29149079] [-0.01140228  2.97091252 -2.26062125] 84 86
# Aligning 8
# [-0.1920298   2.38403379 -1.55339762] [-0.0306953   2.35047849 -1.53413366] 89 90
# Aligning 9
# [-0.11035332  0.87211174 -0.57969058] [-0.09229253  0.88700488 -0.57866848] 91 94
# Aligning 10
# [ 0.  0.  0.] [ 0.  0.  0.] 100 100
# Aligning 11
# [-0.16261019 -1.46273544  0.29173335] [ 0.03225772 -1.4707502   0.29600497] 90 92
# Aligning 12
# [-0.13762449 -1.44954662  0.69149538] [ 0.07209974 -1.45026312  0.72155559] 89 91
# Aligning 13
# [-0.27419838 -2.08257051  1.4567719 ] [-0.14980654 -2.07125459  1.47060679] 84 88
# Aligning 14
# [-0.07115054 -2.62568347  2.10937689] [ 0.07882834 -2.6176069   2.09756996] 80 90
# Aligning 15
# [-0.05977564 -2.95655249  2.46514325] [ 0.08469052 -2.97381047  2.45991795] 80 87
# Aligning 16
# [-0.34015265 -4.43405154  3.11487643] [-0.05029504 -4.42567511  3.11556245] 81 84
# Aligning 17
# [-0.19011885 -4.81250083  3.48083628] [-0.0636378  -4.84199655  3.48143049] 78 85
# Aligning 18
# [-0.09011988 -5.42881291  4.12349263] [-0.10804187 -5.47148491  4.11689141] 75 81
# Aligning 19
# [-0.30575209 -5.78678992  5.52406278] [-0.26893446 -5.81859243  5.53100662] 75 80
# H2R10
# H3R11
# H4R12
# H5R13
# H6R14
# H7R15
# H8R16
# H9R17
# H10R18
# H11R19
# H12R20
# H13R21
# H14R22
# H15R23
# H16R24
# H17R25
# H18R26
# H19R27
# H20R28
# H21R42
# D:\Bogdan\IMR90_5_09_2018\Analysis\Conv_zscan_01__current_cand.pkl
# ['H2R10', 'H3R11', 'H4R12', 'H5R13', 'H6R14', 'H7R15', 'H8R16', 'H9R17', 'H10R18', 'H11R19', 'H12R20', 'H13R21', 'H14R22', 'H15R23', 'H16R24', 'H17R25', 'H18R26', 'H19R27', 'H20R28', 'H21R42']
# Aligning 0
# [
current_cand.pkl
# ['H2R10', 'H3R11', 'H4R12', 'H5R13', 'H6R14', 'H7R15', 'H8R16', 'H9R17', 'H10R18', 'H11R19', 'H12R20', 'H13R21', 'H14R22', 'H15R23', 'H16R24', 'H17R25', 'H18R26', 'H19R27', 'H20R28', 'H21R42']
# Aligning 0
# [  0.0740328   12.62820422 -12.05675362] [  0.04490899  12.57337064 -12.05453165] 55 54
# Aligning 1
# [  0.05631345  11.14201021 -10.06125843] [ -0.02386647  11.10911609 -10.06013988] 60 62
# Aligning 2
# [ 0.1117799   8.72717269 -8.14961515] [-0.02059798  8.71251031 -8.14919019] 64 70
# Aligning 3
# [ 0.09378211  7.38092125 -6.73146832] [-0.01120952  7.39987954 -6.73927831] 66 68
# Aligning 4
# [ 0.16955378  6.70320196 -5.43630955] [ 0.11199753  6.70151069 -5.42249889] 70 79
# Aligning 5
# [ 0.09667193  4.14765311 -4.16082276] [ 0.03436545  4.1427926  -4.15942005] 76 82
# Aligning 6
# [ 0.12541187  2.36883773 -2.56115783] [ 0.00650606  2.36720437 -2.56669559] 79 79
# Aligning 7
# [ 0.28377373  1.91427432 -1.5888536 ] [ 0.1902131   1.91675967 -1.60214564] 84 89
# Aligning 8
# [ 0.05642464  0.63975194 -1.66820664] [-0.00461692  0.63816633 -1.67950165] 90 92
# Aligning 9
# [-0.01757358  0.88175109  0.05800497] [-0.02324045  0.90855646  0.05564778] 89 93
# Aligning 10
# [ 0.  0.  0.] [ 0.  0.  0.] 100 100
# Aligning 11
# [ 0.08355333 -0.46174446  0.24897455] [ 0.03496233 -0.45866133  0.22036133] 84 94
# Aligning 12
# [ 0.01298469 -1.36528563  1.4369252 ] [ 0.05271902 -1.36320013  1.42723328] 81 87
# Aligning 13
# [ 0.11874594 -1.57063893  2.07558656] [ 0.11242522 -1.5939713   2.08203917] 78 84
# Aligning 14
# [ 0.23061629 -2.69430623  2.94137074] [ 0.08057694 -2.70694319  2.94182053] 72 89
# Aligning 15
# [-0.07041422 -4.03569935  3.16412598] [-0.19395082 -4.04675368  3.13778679] 78 85
# Aligning 16
# [ 0.06654894 -3.44340949  3.76952508] [ 0.01198144 -3.45138366  3.7703388 ] 73 84
# Aligning 17
# [-0.02136424 -5.02312133  4.16640289] [-0.03953347 -5.03923052  4.14181538] 66 85
# Aligning 18
# [ 0.03237646 -4.72609875  5.29016165] [-0.04789397 -4.73871366  5.28478912] 65 80
# Aligning 19
# [ 0.22575036 -6.94981259  6.37166387] [ 0.01956825 -6.9456447   6.37293007] 64 77
# H2R10
# H3R11
# H4R12
# H5R13
# H6R14
# H7R15
# H8R16
# H9R17
# H10R18
# H11R19
# H12R20
# H13R21
# H14R22
# H15R23
# H16R24
# H17R25
# H18R26
# H19R27
# H20R28
# H21R42
# D:\Bogdan\IMR90_5_09_2018\Analysis\Conv_zscan_39__current_cand.pkl
# ['H2R10', 'H3R11', 'H4R12', 'H5R13', 'H6R14', 'H7R15', 'H8R16', 'H9R17', 'H10R18', 'H11R19', 'H12R20', 'H13R21', 'H14R22', 'H15R23', 'H16R24', 'H17R25', 'H18R26', 'H19R27', 'H20R28', 'H21R42']
# Aligning 0
# [  0.39516216  13.38648996 -12.4073383 ] [  0.23686552  13.33632834 -12.42082192] 63 58
# Aligning 1
# [ -0.01148937  11.05655115 -10.4329258 ] [ -0.11205313  11.05319429 -10.44069188] 70 63
# Aligning 2
# [-0.02896947  8.64849188 -8.82125218] [-0.10979381  8.67813265 -8.84456298] 74 60
# Aligning 3
# [-0.05118214  7.58104072 -7.05443327] [-0.15109765  7.58385251 -7.05761322] 73 62
# Aligning 4
# [ 0.2890538   5.95788456 -5.34793139] [ 0.11973042  5.94839147 -5.36744092] 80 66
# Aligning 5
# [ 0.27102841  4.58139307 -3.79909279] [ 0.20512837  4.55712959 -3.8071485 ] 80 71
# Aligning 6
# [ 0.3888821   2.83548424 -2.54243693] [ 0.20633116  2.86816738 -2.55644561] 80 75
# Aligning 7
# [ 0.31559137  0.47363649 -1.72086741] [ 0.19720235  0.49760515 -1.73336463] 87 77
# Aligning 8
# [ 0.17775595  0.28906299 -0.95216905] [ 0.09172383  0.30368728 -0.96619119] 90 78
# Aligning 9
# [ 0.3348252  -0.46428438 -0.08581362] [ 0.25068831 -0.42784372 -0.10402364] 86 78
# Aligning 10
# [ 0.  0.  0.] [ 0.  0.  0.] 100 87
# Aligning 11
# [ 0.1715315  -1.55981278  0.51047896] [ 0.23850178 -1.55199127  0.5173007 ] 92 81
# Aligning 12
# [ 0.07059751 -2.05699891  1.02480026] [ 0.02483791 -2.04624563  0.98959302] 87 74
# Aligning 13
# [ 0.13544217 -3.57142319  1.82466975] [ 0.05471982 -3.56078604  1.8074594 ] 83 72
# Aligning 14
# [ 0.07305594 -3.80108353  2.37449142] [-0.02882359 -3.76424132  2.37287011] 85 74
# Aligning 15
# [ 0.06266314 -4.1200439   2.80168837] [-0.00913615 -4.12184769  2.791178  ] 82 71
# Aligning 16
# [ 0.03756713 -4.41347451  3.60492603] [-0.04438466 -4.38790345  3.6059306 ] 81 73
# Aligning 17
# [-0.10429815 -4.6891988   4.06993517] [-0.1273782  -4.66567239  4.04453799] 82 71
# Aligning 18
# [ 0.0534278  -5.04363617  4.21141322] [-0.02913074 -5.03219202  4.18696736] 81 71
# Aligning 19
# [-0.10058211 -6.39335398  6.09029681] [-0.12201331 -6.37026448  6.07758767] 75 65
# H2R10
# H3R11
# H4R12
# H5R13
# H6R14
# H7R15
# H8R16
# H9R17
# H10R18
# H11R19
# H12R20
# H13R21
# H14R22
# H15R23
# H16R24
# H17R25
# H18R26
# H19R27
# H20R28
# H21R42

# %%
folders_in_common#folders_keep_base
# Out:
# []

# %%
reload(tia)
tia.update_candid_spot(im,low_limit,prefered_limit,chr_pts_,txyz_,tag,
                       cutoff_window,cutoff_chr,candid_spot={},fl_cands=None)

# %%
folders_keep
# Out:
# ['D:\\Bogdan\\IMR90_4_25_2018\\H2R10']

# %%
np.array(txyz_both)[2]
# Out:
# [array([-0.06249249,  0.23044066,  0.30037943]),
#  array([ 0.00873513,  0.19062855,  0.45772383])]

# %%
np.array([3])-np.inf
# Out:
# array([-inf])

# %%
os.path.exists(fl_cands)# and not overwrite
# Out:
# True

# %%
candid_spot
# Out:
# {}

# %%
pickle.load(open(r'D:\Bogdan\A549_SI13Ext_D_3_26_2018\Analysis5\Conv_zscan_21__current_cor_v2X.pkl','rb'))
# Out:
# {'H1R9': array([[-0.18844849, -0.05478291, -0.09958932],
#         [ 0.18844849,  0.05478291,  0.09958932]]),
#  'H20R1': array([[-0.17371287, -0.41107573, -0.87147261],
#         [ 0.03868514, -0.39550646, -0.85415891]]),
#  'H21R2': array([[ 0.,  0.,  0.],
#         [ 0.,  0.,  0.]]),
#  'H22R3': array([[-0.15541841, -0.30854442, -0.35422327],
#         [ 0.00431397, -0.33717363, -0.33183036]]),
#  'H23R4': array([[-0.19498527, -0.98761648, -0.89142904],
#         [ 0.02800608, -0.98408981, -0.85627313]]),
#  'H24R5': array([[-0.35025263, -1.01278085, -0.94332314],
#         [ 0.09296144, -0.99196635, -0.92722957]]),
#  'H25R6': array([[-0.26168647, -0.6496551 , -1.05770227],
#         [ 0.05097884, -0.65355239, -1.04699885]]),
#  'H26R7': array([[-0.12782036,  1.81066072,  0.48889034],
#         [ 0.16884796,  1.82515572,  0.45945736]]),
#  'H27R8': array([[-0.05696053,  1.27727627,  1.17395812],
#         [ 0.18666928,  1.26957657,  1.1622168 ]]),
#  'H2R10': array([[-0.46473186,  0.15457567, -1.18363941],
#         [-0.14223603,  0.27351237, -0.9276803 ]]),
#  'H3R11': array([[-0.3536681 , -0.53456773, -1.38518558],
#         [-0.11397061, -0.4422857 , -1.14202816]]),
#  'H4R12': array([[-0.26828651, -0.2317284 , -1.46064739],
#         [-0.07770197, -0.11760696, -1.21880781]]),
#  'H5R13': array([[-0.33019892, -1.84330523, -1.32139995],
#         [-0.05577863, -1.69801868, -1.04949926]]),
#  'H6R14': array([[-0.3558399 , -1.30310865, -1.63782779],
#         [-0.17487791, -1.16912883, -1.46248901]])}

# %%
Aligning 0
[-0.36045557 -1.91663039 -1.79808793] [-0.10502739 -1.75878778 -1.6700326 ] 68 68
Aligning 1
[-0.46473186  0.15457567 -1.18363941] [-0.17651543  0.32043216 -1.00927856] 67 67
Aligning 2
[-0.3536681  -0.53456773 -1.38518558] [-0.19795125 -0.35940894 -1.22554202] 68 68
Aligning 3
[-0.26828651 -0.2317284  -1.46064739] [-0.12236094 -0.07743284 -1.26272727] 69 69

# %%
force_drift
# Out:
# True

# %%
tags
# Out:
# ['H1R9',
#  'H2R10',
#  'H3R11',
#  'H4R12',
#  'H5R13',
#  'H6R14',
#  'H20R1',
#  'H21R2',
#  'H22R3',
#  'H23R4',
#  'H24R5',
#  'H25R6',
#  'H26R7',
#  'H27R8']

# %%
"""
folders_keep = folders[:]
ind=0
fov_id = fov_ids[ind]
im_means=[]
file_=fovs[fov_id]
print file_
ims_cy5,ims_beads,names=[],[],[]
for folder in folders_keep:
    file__= folder+os.sep+file_
    if os.path.exists(file__):
        names+=[os.path.basename(folder)]
        im = tia.DaxReader(file__).loadMap()
        ims_beads += [im[2::2][5:-5]]#/im_beads_repair*np.median(im_beads_repair)]
        ims_cy5 += [im[1::2][5:-5]]#/im_cy5_repair*np.median(im_cy5_repair)]
"""
sz_ex = 75
im = ims_beads[0]
coord_sel1 = np.array(im.shape)/2
im_sm = tia.grab_block(im,coord_sel1,[sz_ex]*3)
#cents1 = get_STD_centers(im_sm)
centers1 = tia.get_seed_points_base(im_sm,gfilt_size=0.75,filt_size=3,th_seed=hseed_beads,hot_pix_th=5)
pfits1 = tia.fit_seed_points_base_fast(im_sm,centers1,width_z=1.,width_xy=1.,radius_fit=5,n_max_iter=10,max_dist_th=0.25)
x,y,z = pfits1[:,1:4].T
plt.figure()
plt.plot(z,y,'rx')
plt.imshow(np.max(im_sm,0),interpolation='nearest',cmap='gray')

im = ims_beads[len(ims_beads)/2]
coord_sel1 = np.array(im.shape)/2
im_sm = tia.grab_block(im,coord_sel1,[sz_ex]*3)
#cents1 = get_STD_centers(im_sm)
centers2 = tia.get_seed_points_base(im_sm,gfilt_size=0.75,filt_size=3,th_seed=hseed_beads,hot_pix_th=5)
pfits2 = tia.fit_seed_points_base_fast(im_sm,centers2,width_z=1.8*1.5/2.,width_xy=1.,radius_fit=5,n_max_iter=10,max_dist_th=0.25)
x,y,z = pfits2[:,1:4].T
plt.figure()
plt.plot(z,y,'rx')
plt.imshow(np.max(im_sm,0),interpolation='nearest',cmap='gray')

plt.show()
# Out:
# Fitting:98 points
# Fitting:47 points

# %%
[-0.09607926 -2.58486963 -0.7264244 ] [-0.09361351 -2.37996744 -0.57876109] 40 53

# %%
tia.translation_aling_pts(pfits1[:,1:4],pfits2[:,1:4],plt_val=True)
# Out:
# array([ 0.15995079,  2.59000803,  0.75762999])

# %%
dic_cor = pickle.load(open(r'D:\Bogdan\A549_SI13Ext_D_3_26_2018\Analysis5\Conv_zscan_21__current_cor_v2.pkl','rb'))
txyz2 =  pickle.load(open(r'D:\Bogdan\A549_SI13Ext_D_3_26_2018\Analysis4\Conv_zscan_21__current_cor.pkl','rb'))

# %%
dic_cor2 =  pickle.load(open(r'D:\Bogdan\A549_SI13Ext_D_3_26_2018\Analysis5\Conv_zscan_02__current_cor_v2.pkl','rb'))

# %%
np.round(np.mean(txyz2[:20],1)-[np.mean(txyz2[:20],1)[1]],2)
# Out:
# array([[ 0.14, -2.1 , -0.63],
#        [ 0.  ,  0.  ,  0.  ],
#        [ 0.04, -0.72, -0.23],
#        [ 0.1 , -0.41, -0.28],
#        [ 0.03, -2.  , -0.12],
#        [ 0.04, -1.47, -0.52],
#        [ 0.03, -0.77, -0.52],
#        [ 0.04, -0.84, -0.39],
#        [ 0.12, -1.02,  0.06],
#        [ 0.01,  0.03,  0.06],
#        [-0.04, -0.59,  0.69],
#        [ 0.13,  0.09,  1.16],
#        [ 0.02, -0.36,  1.29],
#        [ 0.21, -0.28,  1.27],
#        [ 0.15, -0.96,  1.1 ],
#        [ 0.05, -0.31,  1.21],
#        [ 0.19,  0.18,  0.87],
#        [ 0.19,  0.73,  1.19],
#        [ 0.15,  0.  ,  0.82],
#        [ 0.24, -0.7 ,  0.23]])

# %%
dic_cor2[ki[0]],txyz2[0]
# Out:
# (array([[-0.03192648,  0.00714669, -0.01393515],
#         [ 0.03192648, -0.00714669,  0.01393515]]),
#  [array([-0.26057639, -1.4498307 , -0.77176004]),
#   array([-0.09492652, -1.27701033, -0.61995538])])

# %%
keys = dic_cor.keys()
keys2 = dic_cor2.keys()
ki = np.intersect1d(keys,keys2)
ki = np.array(ki)[np.argsort(map(get_hybe,ki))]
#[(k,np.mean(dic_cor[k],0)-np.mean(dic_cor2[k],0)) for k in ki]
np.round(np.array([np.mean(dic_cor2[k],0) for k in ki])-[np.mean(dic_cor2[ki[1]],0)],2)
# Out:
# array([[ 0.11,  1.65, -0.36],
#        [ 0.  ,  0.  ,  0.  ],
#        [ 0.14,  0.76, -0.59],
#        [ 0.  ,  1.06, -0.58],
#        [ 0.06,  0.96, -0.95],
#        [ 0.01,  1.43, -0.27],
#        [ 0.21,  0.23, -0.92],
#        [ 0.14,  0.06, -0.41],
#        [ 0.04,  0.88, -0.68],
#        [-0.05,  0.7 , -0.86],
#        [ 0.12,  1.31, -0.78],
#        [-0.08,  1.45, -0.66],
#        [ 0.11,  1.2 , -1.  ],
#        [ 0.15,  0.61, -1.19],
#        [ 0.15,  0.84, -1.23],
#        [ 0.09,  1.06, -1.11],
#        [ 0.2 , -0.5 , -0.42],
#        [ 0.08,  0.85, -1.06],
#        [ 0.02,  2.16, -0.63],
#        [ 0.02,  1.67, -1.23],
#        [ 0.03,  1.2 , -0.74],
#        [ 0.15,  2.75, -0.95],
#        [ 0.01,  1.66, -0.79],
#        [ 0.16,  1.24, -0.81],
#        [ 0.1 ,  1.55, -0.61],
#        [ 0.16,  1.52, -0.46],
#        [ 0.13,  2.32, -0.41],
#        [ 0.17,  1.34, -0.62],
#        [ 0.2 ,  2.48, -0.55],
#        [ 0.13,  1.24,  0.22],
#        [ 0.19,  0.99,  0.33],
#        [ 0.11,  2.33, -0.17],
#        [ 0.07,  1.54, -0.56],
#        [ 0.02,  1.3 , -0.73],
#        [ 0.27,  2.21, -0.41],
#        [ 0.21,  2.16, -0.48],
#        [ 0.04,  1.58,  0.06],
#        [ 0.28, -0.19, -0.19],
#        [ 0.2 ,  1.89, -1.26],
#        [ 0.11,  1.65, -0.36],
#        [ 0.11,  3.54, -0.41],
#        [ 0.18,  3.12, -0.31],
#        [ 0.14,  2.31, -0.29],
#        [ 0.21,  1.76,  0.09],
#        [ 0.2 ,  1.25, -0.17],
#        [ 0.08,  0.68, -0.25],
#        [ 0.1 ,  1.8 ,  0.1 ],
#        [ 0.27,  0.84,  0.01],
#        [ 0.18,  1.74, -0.07],
#        [ 0.14, -0.44,  0.72],
#        [ 0.22,  0.51, -0.1 ],
#        [ 0.11,  1.59, -0.23],
#        [ 0.08,  1.14, -0.11],
#        [ 0.14,  1.49, -0.63],
#        [ 0.07,  0.18, -0.02],
#        [ 0.04,  0.08, -0.53],
#        [ 0.18,  0.97, -0.63],
#        [ 0.13,  0.49, -1.18],
#        [ 0.23,  1.36, -0.45],
#        [ 0.32,  1.97, -0.31],
#        [ 0.17,  1.83, -0.04],
#        [ 0.16,  1.03, -0.16],
#        [ 0.15,  1.55,  0.1 ],
#        [ 0.2 ,  0.42, -0.14],
#        [ 0.22,  2.03, -0.34],
#        [ 0.34,  2.38,  0.28],
#        [ 0.23,  1.33,  0.54],
#        [ 0.11,  3.1 ,  1.88],
#        [ 0.23,  2.56,  2.1 ],
#        [ 0.13,  1.77,  2.98],
#        [ 0.22,  1.48,  2.2 ],
#        [ 0.14,  2.06,  1.89],
#        [ 0.18,  2.14,  2.17],
#        [ 0.19,  1.5 ,  2.05],
#        [ 0.02,  2.9 ,  2.47],
#        [ 0.12,  1.8 ,  2.27],
#        [ 0.15,  3.48,  2.04]])

# %%
dic_cor['H1R9']
# Out:
# array([[-0.01757451,  0.05441316,  0.01411211],
#        [ 0.01757451, -0.05441316, -0.01411211]])

# %%
dists = cdist(chr_pts_,centers)
mindist = np.min(dists,0)
keep = mindist<cutoff_window #keep only points within a distince cutoff_window from a chromosome
print dists.shape
centersh_close = centersh[keep]
# Out:
# (41L, 271L)

# %%
reload(tia)
#tia.get_STD_centers(ims_beads[0],hseed=150,nseed=500,plt_val=True)
tia.get_STD_beaddrift(ims_beads[:3],sz_ex=75,hseed=100,nseed=100,ref=None,force=True)#,save_file=save_file)
# Out:
# Aligning 0
# [-0.27847422 -5.60937106 -0.64613467] [-0.26486985 -5.58067618 -0.66107494]
# Aligning 1
# [ 0.  0.  0.] [ 0.  0.  0.]
# Aligning 2
# [-0.14559252  1.01004937  0.15957446] [-0.19759638  1.00774016  0.1864611 ]
# ([[array([-0.27847422, -5.60937106, -0.64613467]),
#    array([-0.26486985, -5.58067618, -0.66107494])],
#   [array([ 0.,  0.,  0.]), array([ 0.,  0.,  0.])],
#   [array([-0.14559252,  1.01004937,  0.15957446]),
#    array([-0.19759638,  1.00774016,  0.1864611 ])]],
#  True)

# %%
reload(tia)
# Out:
# <module 'TadImagingAnalysis' from 'C:\Data\Alistair\code\python-functions\python-functions-library\TadImagingAnalysis.py'>

# %%
cdist

# %%
plt.plot(x,y,'o')
plt.show()

# %%
candid_dic[tag]=np.array(self.pfits)#drif corrected
candid_spot[i_master]=(candid_dic,np.array(master[::-1]))
candid_dic[tag] =
# Out:
# 57

# %%
len(ims_cy5)
# Out:
# 1

# %%
candid_spot[i_master]=(candid_dic,np.array(master[::-1]))

# %%
#Power up the GUI and run across all fov and chroms selected
reload(tia)
overwrite=False
analysis_folder = master_folder+os.sep+r'Analysis1'
if not os.path.exists(analysis_folder):
    os.makedirs(analysis_folder)
folders_keep = folders
for ind in range(len(fov_ids)):
    try:
        plt.close('all')
        candid_spot = {}
        candid_spotS = {}

        fov_id = fov_ids[ind]
        fl_cands = analysis_folder+os.sep+fovs[fov_id].replace('.dax','__current_cand.pkl')#file where it save candidates
        fl_candsS = analysis_folder+os.sep+fovs[fov_id].replace('.dax','__current_candS.pkl')#file where it save candidates
        fl_finished = analysis_folder+os.sep+fovs[fov_id].replace('.dax','.finished')#file where it marks finished
        file_=fovs[fov_id]
        print file_
        if not os.path.exists(fl_finished) or overwrite:
            if os.path.exists(fl_cands) and not overwrite:
                candid_spot = pickle.load(open(fl_cands,'rb'))
            if os.path.exists(fl_candsS) and not overwrite:
                candid_spotS = pickle.load(open(fl_candsS,'rb'))
            ims_cy5,ims_beads,names=[],[],[]
            for folder in folders_keep:
                file__= folder+os.sep+file_
                if os.path.exists(file__):
                    print file__
                    names+=[os.path.basename(folder)]
                    im = tia.DaxReader(file__).loadMap()
                    ims_beads += [im[2::2][5:-5]/im_beads_repair*np.median(im_beads_repair)]
                    ims_cy5 += [im[1::2][5:-5]/im_cy5_repair*np.median(im_cy5_repair)]

            chroms = tia.imshow_mark_3d_v2(ims_cy5,image_names=names)

            chroms.width_z = 1.8*1.5/2.
            chroms.hot_pix_th=4

            from scipy.spatial.distance import cdist

            fov_id = fov_ids[ind]
            chr_pts_ = chr_pts[ind]

            self=chroms
            cutoff_trace=10
            dm =20#dimension of cube where to zoom in (actually 60 pix)
            ref=0
            #compute the drift
            save_file = analysis_folder+os.sep+fovs[fov_id].replace('.dax','__current_cor.pkl')
            txyz_both,overwrite = tia.get_STD_beaddrift(ims_beads,sz_ex=75,hseed=200,ref=None,force=False,save_file=save_file)
            if len(np.array(txyz_both).shape)==3:
                txyz = np.mean(txyz_both,1)
            else:
                txyz = txyz_both
            txyz = np.array(txyz)-[txyz[ref]]

            for i_master,master in enumerate(chr_pts_):
                if not candid_spot.has_key(i_master):
                    self.ax2.set_ylim(master[2]+dm+dm/2,master[2]-dm-dm/2)
                    class_ids_new,coords_new=[],[]
                    candid_dic={}#this gets saved to file
                    candid_dicS={}
                    #for each chr you have a candid_dic. the candid_dic dictionary goes across hybes and reports a list of fits
                    sel_cl_dic={}
                    sel_max_dic={}
                    for self.index_im in range(len(self.ims)):
                        self.set_image()
                        drift_x,drift_y,drift_z = txyz[self.index_im][::-1]
                        #drift_x,drift_y = int(drift_x),int(drift_y)
                        drift_x,drift_y = int(np.min([drift_x,2*self.ims[0].shape[-2]])),int(np.min([drift_y,2*self.ims[0].shape[-1]]))
                        self.ax1.set_xlim(master[0]+drift_x-dm,master[0]+drift_x+dm)#
                        self.ax1.set_ylim(master[1]+drift_y+dm,master[1]+drift_y-dm)#
                        self.auto_scale()
                        self.th_seed=250
                        self.get_seed_points()
                        self.fit_seed_points()
                        if len(self.pfits)==0:
                            self.th_seed=150
                            self.get_seed_points()
                            self.fit_seed_points()
                        ids=np.array(self.class_ids)
                        coords=np.array(self.coords)

                        if len(self.pfits)>0:
                            tag = os.path.basename(self.image_names[self.index_im])
                            candid_dic[tag]=np.array(self.pfits)
                            candid_dic[tag][:,1:4]=candid_dic[tag][:,1:4]-[txyz[self.index_im]]#apply drift correction

                            all_pts_hybe = candid_dic[tag][:,1:4]
                            chr_pts_comp =[pt__[::-1]for pt__ in chr_pts_]
                            inds = np.argmin(cdist(all_pts_hybe,chr_pts_comp),-1)
                            keep = inds==i_master
                            candid_dicS[tag] = np.array(candid_dic[tag])
                            candid_dic[tag] = candid_dic[tag][keep]

                            if np.sum(keep)>0:
                                coords_new.append(self.pfits[keep][0][1:4][::-1])
                                class_ids_new.append(self.index_im)
                            self.coords=coords_new
                            self.class_ids=class_ids_new
                            self.populate_draw_xyz()
                            self.set_image()
                    candid_spot[i_master]=(candid_dic,np.array(master[::-1]))
                    candid_spotS[i_master]=(candid_dic,np.array(master[::-1]))
                    pickle.dump(candid_spot,open(fl_cands,'wb'))
                    pickle.dump(candid_spotS,open(fl_candsS,'wb'))
            fid = open(fl_finished,'wb')
            fid.close()
    except:
        print "Failed"
