# %%
# %run C:\Users\puzheng\Documents\Startup_py3.py
sys.path.append(r'C:\Users\puzheng\Documents')
# %matplotlib notebook
import ImageAnalysis3 as ia
from ImageAnalysis3 import get_img_info, visual_tools, corrections

# %%
# master folder for this dataset:
#master_folder = r'L:/20180618_chr21_9x36/';
master_folder = r'L:20180607_chr21FISH_5x10_150regs/'
# get Folders, Field-of-views
folders, fovs = ia.get_img_info.get_folders(master_folder, feature='H', verbose=True)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 38
# - Number of field of views: 70

# %%
fov_id = 0
#e_type = 'unique'
e_type = 'combo'

# %%
segmentation_label, dapi_im = ia.analysis.Segmentation_Fov(master_folder, folders, fovs, fov_id, num_channel=4)
# Out:
# - load segmentation result from filename: L:20180607_chr21FISH_5x10_150regs/\Analysis\segmentation\Conv_zscan_00_segmentation.pkl

# %%
cell_list, color_dic, colors, encoding_scheme = ia.analysis.Crop_Images_Field_of_View(master_folder, 
                                                                                folders, 
                                                                                fovs, 
                                                                                fov_id, 
                                                                                segmentation_label, 
                                                                                dapi_im, 
                                                                                drift_corr_size=150,
                                                                                encoding_type=e_type,
                                                                                save=False, dynamic=True)
# save raw data
#make_save = ia.analysis.Save_Cell_List(cell_list, e_type, fovs[fov_id], master_folder, postfix='_test',analysis_path='test')
# Out:
# Loading color usage
# - Importing csv file: L:20180607_chr21FISH_5x10_150regs/\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# - Hyb 0 exists in this data
# -- DAPI exists
# Loading images for field of view 0
# Get images of a fov (ia.get_img_info.get_img_fov)
# - loading field of view: Conv_zscan_00.dax
# - number of images loaded: 38
# Splitting total images into different channels
# Split multi-channel images (ia.get_img_info.split_channels)
# -- number of channels: 4
# -- scanning through images to find images with DAPI:
# Correcting drifts
# Processing combo images
# - Importing csv file: L:20180607_chr21FISH_5x10_150regs/\Encoding_Scheme.csv
# -- hyb per group: 5
# -- region per group: 10
# -- number of colors: 3
# - Number of cells in fov: 9
# Start corpping images in all channels
# - processing channel: 561
# -- processing folders: ['H1R1', 'H2R2', 'H3R3', 'H4R4', 'H5R5']
# -- processing folders: ['H6R6', 'H7R7', 'H8R8', 'H9R9', 'H10R10']
# ...

# %%
cell_list = ia.analysis.compressive_sensing_decomposition(master_folder, 
                                                           fovs[fov_id], 
                                                           cell_list, 
                                                           color_dic, 
                                                           encoding_scheme, save=False, force=False)
# Out:
# - check existence of savefile: True
# - loading savefile L:20180607_chr21FISH_5x10_150regs/\Analysis\Conv_zscan_00_cs_list.pkl

# %%
# add chromosome info
cell_list = ia.analysis.generate_chromosome_from_cell_list(cell_list, encoding_type=e_type)
cell_list, seg_labels = ia.analysis.identify_chromosome(cell_list, return_im=True)
# Out:
# - generating chromosome from cell_list.
# -- calculating mean profile of cell 0
# C:\Users\puzheng\AppData\Local\Continuum\Anaconda2\envs\py36\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# -- calculating mean profile of cell 1
# -- calculating mean profile of cell 2
# -- calculating mean profile of cell 3
# -- calculating mean profile of cell 4
# -- calculating mean profile of cell 5

# %%
reload(ia.analysis)
reload(ia.get_img_info)
reload(ia.visual_tools)
reload(ia.corrections)
# Out:
# <module 'ImageAnalysis3.corrections' from 'C:\\Users\\puzheng\\Documents\\ImageAnalysis3\\corrections.py'>

# %%
# fit candidate spots
cell_list = ia.analysis.candidate_spots_in_chromosome(cell_list, 
                                                      encoding_type=e_type, 
                                                      encoding_scheme=encoding_scheme)
# Out:
# - fit candidate spots given chromosomes
# -- processing cell: 0 with chromosome: 2
# C:\Users\puzheng\AppData\Local\Continuum\Anaconda2\envs\py36\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# -- processing cell: 1 with chromosome: 2
# -- processing cell: 2 with chromosome: 2
# -- processing cell: 3 with chromosome: 2
# -- processing cell: 4 with chromosome: 1
# -- processing cell: 5 with chromosome: 1

# %%
# generate distance map
cell_list = ia.analysis.generate_distance_map(cell_list, make_plot=True)
# Out:
# - calculate distance map
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
cell_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1b3f4ff71a4b> in <module>()
# ----> 1 cell_list
#
# NameError: name 'cell_list' is not defined
